# %% [markdown]
# #### A total of 15 print-heads were randomly selected and tested until failure. The durability of each print-head (in millions of characters) was recorded as follows:
# #### 1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29

# %%
import numpy as np
from scipy import stats

# %%
data = [1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29]
n = len(data)
mean = np.mean(data)
std = np.std(data,ddof=1)
print(f'sample size = {n}')
print(f'sample mean = {mean:.2f}')
print(f'sample standard deviation = {std:.2f}')
# Out:
# sample size = 15
# sample mean = 1.24
# sample standard deviation = 0.19

# %% [markdown]
# #### Build 99% Confidence Interval Using Sample Standard Deviation
#     Assuming the sample is representative of the population, construct a 99% confidence interval for the mean number of characters printed before the print-head fails using the sample standard deviation. Explain the steps you take and the rationale behind using the t-distribution for this task.

# %%
c = 0.99 #confidence
alpha = 1 - c #significance level
df = n - 1 #degree of freedom  
### we use t-distribution because here n is less the 30 unknow std
Confidence_Interval_t = stats.t.interval(c,loc= mean,df=n-1,scale= std/np.sqrt(n))
print(f'99% Confidence Interval Using Sample Standard Deviation (t - distribution) is {Confidence_Interval_t}')
# Out:
# 99% Confidence Interval Using Sample Standard Deviation (t - distribution) is (np.float64(1.0901973384384906), np.float64(1.3871359948948425))

# %% [markdown]
# #### Build 99% Confidence Interval Using Known Population Standard Deviation
#     If it were known that the population standard deviation is 0.2 million characters, construct a 99% confidence interval for the mean number of characters printed before failure.

# %%
c = 0.99 #cofindence
alpha = 1 - c #significance level
pop_std = 0.2
Confidence_Interval_z=stats.norm.interval(c,loc=mean,scale= pop_std/np.sqrt(n))
print(f'99% Confidence Interval Using Known Population Standard Deviation is {Confidence_Interval_z}')
# Out:
# 99% Confidence Interval Using Known Population Standard Deviation is (np.float64(1.1056514133957607), np.float64(1.3716819199375725))
